# %% [markdown]
# ### Importing library and files

# %%
# Importing NumPy and Pandas.
import numpy as np
import pandas as pd

# Importing matplotlib.pyplot - the specific plotting API 
# https://matplotlib.org/api/pyplot_api.html
import matplotlib.pyplot as plt

# Import Seaborn.
import seaborn as sns

# %%
#Bring in the SAT files 
SAT_2017 = pd.read_csv("../data/sat_2017.csv")
SAT_2018 = pd.read_csv("../data/sat_2018.csv")
SAT_2019 = pd.read_csv("../data/sat_2019.csv")
SAT_2019_col_mjr = pd.read_csv("../data/sat_2019_by_intended_college_major.csv")
SAT_2019_ca = pd.read_csv("../data/sat_2019_ca.csv")

#Bring in the ACT files 
ACT_2017 = pd.read_csv("../data/act_2017.csv")
ACT_2018 = pd.read_csv("../data/act_2018_old.csv")
ACT_2019 = pd.read_csv("../data/act_2019_old.csv")
ACT_2019_ca = pd.read_csv("../data/act_2019_ca.csv")

#Bring in SAT&ACT files
SAT_ACT = pd.read_csv("../data/sat_act_by_college.csv")

# %% [markdown]
# Library
# - State = State
# - Participation = Participation in percent of the state’s high school graduates
# - Evidence-Based Reading and Writing	= Reading Test and Writing and Language Test Score
# - Math = Math score
# - Total = total score

# %% [markdown]
# # Cleaning and Preparing Data

# %% [markdown]
# ## SAT

# %% [markdown]
# ### Exploring on SAT Data

# %%
print ((SAT_2017).columns)
print ((SAT_2017['State']).nunique)
SAT_2017.head()
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')
# <bound method IndexOpsMixin.nunique of 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# ...

# %%
print ((SAT_2018).columns)
print ((SAT_2018['State']).nunique)
SAT_2018.head()
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')
# <bound method IndexOpsMixin.nunique of 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# ...

# %%
print ((SAT_2019).columns)
print ((SAT_2019['State']).nunique)
SAT_2019.head()
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')
# <bound method IndexOpsMixin.nunique of 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# ...

# %%
print ((SAT_2019_col_mjr).columns)
print(f'shape {SAT_2019_col_mjr.shape}')
SAT_2019_col_mjr.head(38)
# Out:
# Index(['IntendedCollegeMajor', 'TestTakers', 'Percent', 'Total',
#        'ReadingWriting', 'Math'],
#       dtype='object')
# shape (38, 6)
#                                  IntendedCollegeMajor TestTakers Percent  \
# 0   Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                   Architecture and Related Services     28,988      2%
# 2          Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 3                  Biological and Biomedical Sciences    155,834      8%
# 4   Business, Management, Marketing, and Related S...    221,523     12%
# 5     Communication, Journalism, and Related Programs     36,332      2%
# 6   Computer and Information Sciences and Support ...     79,736      4%
# 7                        Construction Trades, General      2,500      0%
# 8                                           Education     71,882      4%
# 9                                         Engineering    194,127     11%
# ...

# %%
print ((SAT_2019_ca).columns)
SAT_2019_ca.head(2).T
# Out:
# Index(['CDS', 'CCode', 'CDCode', 'SCode', 'RType', 'SName', 'DName', 'CName',
#        'Enroll12', 'NumTSTTakr12', 'NumERWBenchmark12', 'PctERWBenchmark12',
#        'NumMathBenchmark12', 'PctMathBenchmark12', 'Enroll11', 'NumTSTTakr11',
#        'NumERWBenchmark11', 'PctERWBenchmark11', 'NumMathBenchmark11',
#        'PctMathBenchmark11', 'TotNumBothBenchmark12', 'PctBothBenchmark12',
#        'TotNumBothBenchmark11', 'PctBothBenchmark11', 'Year', 'Unnamed: 25'],
#       dtype='object')
#                                              0                1
# CDS                            6615980630046.0  6616060634758.0
# CCode                                      6.0              6.0
# CDCode                                661598.0         661606.0
# SCode                                 630046.0         634758.0
# RType                                        S                S
# SName                  Colusa Alternative Home  Maxwell Sr High
# ...

# %%
SAT_ACT['School'].nunique()
# Out:
# 416

# %%
SAT_ACT['Test Optional?'].unique()
# Out:
# array(['Yes', 'Yes (TB)', 'Yes*', 'Yes (TF)', 'No'], dtype=object)

# %%
SAT_ACT
# Out:
#                                     School Test Optional?  \
# 0                      Stanford University            Yes
# 1                          Harvard College            Yes
# 2                     Princeton University            Yes
# 3                      Columbia University            Yes
# 4                          Yale University            Yes
# ..                                     ...            ...
# 411  University of Texas Rio Grande Valley             No
# 412             University of South Dakota             No
# 413              University of Mississippi             No
# 414                  University of Wyoming             No
# 415            University of Texas El Paso             No
#
#     Applies to Class Year(s)  \
# 0                       2021
# 1                       2021
# 2                       2021
# 3                       2021
# 4                       2021
# ..                       ...
# 411                      NaN
# ...

# %% [markdown]
# ### Cleaning data SAT

# %%
SAT_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
SAT_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
SAT_2019.info()

#there are 53 states
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
SAT_2019_col_mjr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IntendedCollegeMajor  38 non-null     object
#  1   TestTakers            38 non-null     object
#  2   Percent               38 non-null     object
#  3   Total                 38 non-null     int64
#  4   ReadingWriting        38 non-null     int64
#  5   Math                  38 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1.9+ KB

# %%
SAT_2019_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   float64
#  2   CDCode                 2579 non-null   float64
#  3   SCode                  2579 non-null   float64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   float64
#  9   NumTSTTakr12           2579 non-null   float64
#  10  NumERWBenchmark12      2304 non-null   object
#  11  PctERWBenchmark12      2304 non-null   object
#  12  NumMathBenchmark12     2304 non-null   object
#  13  PctMathBenchmark12     2304 non-null   object
# ...

# %%
SAT_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
SAT_2018.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
SAT_2019.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
SAT_2019_col_mjr.isnull().sum()
# Out:
# IntendedCollegeMajor    0
# TestTakers              0
# Percent                 0
# Total                   0
# ReadingWriting          0
# Math                    0
# dtype: int64

# %%
SAT_2019_ca.isnull().sum()
# Out:
# CDS                         1
# CCode                       1
# CDCode                      1
# SCode                       1
# RType                       1
# SName                     598
# DName                      59
# CName                       1
# Enroll12                    1
# NumTSTTakr12                1
# NumERWBenchmark12         276
# PctERWBenchmark12         276
# NumMathBenchmark12        276
# PctMathBenchmark12        276
# Enroll11                    1
# NumTSTTakr11                1
# NumERWBenchmark11         311
# PctERWBenchmark11         311
# NumMathBenchmark11        311
# PctMathBenchmark11        311
# TotNumBothBenchmark12     276
# PctBothBenchmark12        276
# TotNumBothBenchmark11     311
# PctBothBenchmark11        311
# Year                        1
# Unnamed: 25              2580
# dtype: int64

# %%
# changing the columns to the be the same as the 2 remaining files
SAT_2018.rename(columns={'Evidence-Based Reading and Writing':"EBRW"}, inplace = True)
SAT_2018.head(5)
SAT_2017.rename(columns={'Evidence-Based Reading and Writing':"EBRW"}, inplace = True)
SAT_2017.head(5)
# Out:
#         State Participation  EBRW  Math  Total
# 0     Alabama            5%   593   572   1165
# 1      Alaska           38%   547   533   1080
# 2     Arizona           30%   563   553   1116
# 3    Arkansas            3%   614   594   1208
# 4  California           53%   531   524   1055

# %%
#remove 3 Non-US states from SAT_2017-19: wanted to focus on only the data from US states only 

SAT_2017 = SAT_2017[SAT_2017['State'] != "Virgin Islands"]
SAT_2018 = SAT_2018[SAT_2018['State'] != "Virgin Islands"]
SAT_2019 = SAT_2019[SAT_2019['State'] != "Virgin Islands"]
SAT_2017 = SAT_2017[SAT_2017['State'] != "Puerto Rico"]
SAT_2018 = SAT_2018[SAT_2018['State'] != "Puerto Rico"]
SAT_2019 = SAT_2019[SAT_2019['State'] != "Puerto Rico"]

# %% [markdown]
# SAT 2017

# %%
SAT_2017.columns
# Out:
# Index(['State', 'Participation', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
SAT_2017.shape
# Out:
# (51, 5)

# %%
SAT_2017.dtypes
# Out:
# State            object
# Participation    object
# EBRW              int64
# Math              int64
# Total             int64
# dtype: object

# %%
SAT_2017['Participation'].dtypes
# Out:
# dtype('O')

# %%
SAT_2017['Participation'] = SAT_2017['Participation'].replace({'%':''}, regex = True)

# %%
SAT_2017['Participation'] = SAT_2017['Participation'].apply(pd.to_numeric, errors = 'coerce')

# %%
SAT_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     int64
#  2   EBRW           51 non-null     int64
#  3   Math           51 non-null     int64
#  4   Total          51 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# SAT 2018

# %%
SAT_2018.columns
# Out:
# Index(['State', 'Participation', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
SAT_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   EBRW           51 non-null     int64
#  3   Math           51 non-null     int64
#  4   Total          51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
SAT_2018['Participation'] = SAT_2018['Participation'].replace({'%':''}, regex = True)

# %%
SAT_2018['Participation'] = SAT_2018['Participation'].apply(pd.to_numeric, errors = 'coerce')

# %%
SAT_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     int64
#  2   EBRW           51 non-null     int64
#  3   Math           51 non-null     int64
#  4   Total          51 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# SAT 2019

# %%
SAT_2019.columns
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
SAT_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     object
#  2   EBRW                51 non-null     int64
#  3   Math                51 non-null     int64
#  4   Total               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.4+ KB

# %%
SAT_2019.rename(columns={'Participation Rate':"Participation"}, inplace = True)

# %%
SAT_2019['Participation'] = SAT_2019['Participation'].replace({'%':''}, regex = True)

# %%
SAT_2019['Participation'] = SAT_2019['Participation'].apply(pd.to_numeric, errors = 'coerce')

# %%
SAT_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     int64
#  2   EBRW           51 non-null     int64
#  3   Math           51 non-null     int64
#  4   Total          51 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# #### Analysis 2017

# %%
SAT_2017.describe()
# Out:
#        Participation        EBRW        Math        Total
# count      51.000000   51.000000   51.000000    51.000000
# mean       39.803922  569.117647  547.627451  1126.098039
# std        35.276632   45.666901   84.909119    92.494812
# min         2.000000  482.000000   52.000000   950.000000
# 25%         4.000000  533.500000  522.000000  1055.500000
# 50%        38.000000  559.000000  548.000000  1107.000000
# 75%        66.000000  613.000000  599.000000  1212.000000
# max       100.000000  644.000000  651.000000  1295.000000

# %%
ACT_2018[ACT_2018['State'] =='South Dakota']
# Out:
#            State Participation  Composite
# 42  South Dakota           77%       21.9

# %%
# calculating which state that fail to pass EBRW (score less than 400)
states_below_400 = SAT_2017[SAT_2017['EBRW'] < 400]
states_below_400
# Out:
# Empty DataFrame
# Columns: [State, Participation, EBRW, Math, Total]
# Index: []

# %%
# calculating which state that fail to pass Math (score less than 400)
states_below_400 = SAT_2017[SAT_2017['Math'] < 400]
print(states_below_400['State'].unique())
states_below_400
# Out:
# ['Maryland']
#        State  Participation  EBRW  Math  Total
# 20  Maryland             69   536    52   1060

# %%
# calculating which state that fail to pass EBRW and Math (Total score less than 800)
states_below_400 = SAT_2017[SAT_2017['Total'] < 400]
states_below_400['State'].unique()
# Out:
# array([], dtype=object)

# %%
# checking out the states that has high participation % but the score are below standard

# %%
SAT_2017[SAT_2017['State'] == "Maryland"].head()
# Out:
#        State  Participation  EBRW  Math  Total
# 20  Maryland             69   536    52   1060

# %% [markdown]
# #### Analysis 2018

# %%
SAT_2018.describe()
# Out:
#        Participation        EBRW        Math        Total
# count      51.000000   51.000000   51.000000    51.000000
# mean       45.745098  563.686275  556.235294  1120.019608
# std        37.314256   47.502627   47.772623    94.155083
# min         2.000000  480.000000  480.000000   977.000000
# 25%         4.500000  534.500000  522.500000  1057.500000
# 50%        52.000000  552.000000  544.000000  1098.000000
# 75%        77.500000  610.500000  593.500000  1204.000000
# max       100.000000  643.000000  655.000000  1298.000000

# %%
# calculating which state that fail to pass Math (score less than 400)
states_below_400 = SAT_2018[SAT_2018['EBRW'] < 400]
print(states_below_400['State'].unique())
states_below_400
# Out:
# []
# Empty DataFrame
# Columns: [State, Participation, EBRW, Math, Total]
# Index: []

# %%
# calculating which state that fail to pass Math (score less than 400)
states_below_400 = SAT_2018[SAT_2018['Math'] < 400]
print(states_below_400['State'].unique())
states_below_400
# Out:
# []
# Empty DataFrame
# Columns: [State, Participation, EBRW, Math, Total]
# Index: []

# %%
ACT_2018[ACT_2018['State'] =='South Dakota']
# Out:
#            State Participation  Composite
# 42  South Dakota           77%       21.9

# %% [markdown]
# #### Analysis 2019

# %%
SAT_2019.describe()
# Out:
#        Participation        EBRW        Math        Total
# count      51.000000   51.000000   51.000000    51.000000
# mean       49.058824  560.803922  552.196078  1113.078431
# std        38.747600   46.248035   51.290553    97.197910
# min         2.000000  483.000000  460.000000   943.000000
# 25%         5.500000  527.500000  511.500000  1038.000000
# 50%        54.000000  550.000000  546.000000  1097.000000
# 75%        82.000000  612.000000  599.000000  1210.000000
# max       100.000000  636.000000  648.000000  1284.000000

# %%
# calculating which state that fail to pass Math (score less than 400)
states_below_400 = SAT_2019[SAT_2019['EBRW'] < 400]
print(states_below_400['State'].unique())
states_below_400
# Out:
# []
# Empty DataFrame
# Columns: [State, Participation, EBRW, Math, Total]
# Index: []

# %%
# calculating which state that fail to pass Math (score less than 400)
states_below_400 = SAT_2019[SAT_2019['Math'] < 400]
print(states_below_400['State'].unique())
states_below_400
# Out:
# []
# Empty DataFrame
# Columns: [State, Participation, EBRW, Math, Total]
# Index: []

# %% [markdown]
# ### Merge data files SAT

# %% [markdown]
# #### SAT

# %%
# changing the name of the columns in each files to be with the year (to merge into the same file later)
SAT_2018.rename(columns={'EBRW':"eng_18", 'Math':'math_18', 'Total':'total_18','Participation':'participation_18'}, inplace = True)
SAT_2017.rename(columns={'EBRW':"eng_17", 'Math':'math_17', 'Total':'total_17','Participation':'participation_17'}, inplace = True)
SAT_2019.rename(columns={'EBRW':"eng_19", 'Math':'math_19', 'Total':'total_19','Participation':'participation_19'}, inplace = True)

#set state into index
SAT_2017.set_index('State', inplace=True)
SAT_2019.set_index('State', inplace=True);
SAT_2018.set_index('State', inplace=True);

# %%
# Merge three SAT files base on State
merge_17_18 = SAT_2017.join(SAT_2018)

#Merge to 2019 SAT, given the name merge_sat
merge_sat = merge_17_18.join(SAT_2019)

#checking 
merge_sat
# Out:
#                       participation_17  eng_17  math_17  total_17  \
# State
# Alabama                              5     593      572      1165
# Alaska                              38     547      533      1080
# Arizona                             30     563      553      1116
# Arkansas                             3     614      594      1208
# California                          53     531      524      1055
# Colorado                            11     606      595      1201
# Connecticut                        100     530      512      1041
# Delaware                           100     503      492       996
# District of Columbia               100     482      468       950
# Florida                             83     520      497      1017
# Georgia                             61     535      515      1050
# Hawaii                              55     544      541      1085
# Idaho                               93     513      493      1005
# ...

# %% [markdown]
# #### ACT

# %%
ACT_2018.head(1)
# Out:
#      State Participation  Composite
# 0  Alabama          100%       19.1

# %%
ACT_2018.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
# changing the name of the columns in each files to be with the year (to merge into the same file later)
ACT_2018.rename(columns={'Participation':'participation_18','Composite':'avg_18'}, inplace = True)
ACT_2017.rename(columns={'Participation':'participation_17','Composite':'avg_17'}, inplace = True)
ACT_2019.rename(columns={'Participation':'participation_19','Composite':'avg_19'}, inplace = True)

# %%
ACT_2018.columns
# Out:
# Index(['State', 'participation_18', 'avg_18'], dtype='object')

# %%
ACT_2017.columns
# as there are a
# Out:
# Index(['State', 'participation_17', 'English', 'Math', 'Reading', 'Science',
#        'avg_17'],
#       dtype='object')

# %%
ACT_2019.columns
# as there are a
# Out:
# Index(['State', 'participation_19', 'avg_19'], dtype='object')

# %%
ACT_2019.head(2)
# Out:
#      State participation_19  avg_19
# 0  Alabama             100%    18.9
# 1   Alaska              38%    20.1

# %%
ACT_2018.head(2)
# Out:
#      State participation_18  avg_18
# 0  Alabama             100%    19.1
# 1   Alaska              33%    20.8

# %% [markdown]
# ## ACT

# %% [markdown]
# ### Exploring on ACT Data

# %%
print ((ACT_2017).columns)
print ((ACT_2017['State']).nunique)
print ((ACT_2017).info())
ACT_2017 = ACT_2017.drop(['English', 'Math', 'Reading', 'Science'], axis=1)
ACT_2017.head()
# Out:
# Index(['State', 'participation_17', 'English', 'Math', 'Reading', 'Science',
#        'avg_17'],
#       dtype='object')
# <bound method IndexOpsMixin.nunique of 0                 National
# 1                  Alabama
# 2                   Alaska
# 3                  Arizona
# 4                 Arkansas
# 5               California
# 6                 Colorado
# 7              Connecticut
# 8                 Delaware
# 9     District of Columbia
# 10                 Florida
# 11                 Georgia
# 12                  Hawaii
# 13                   Idaho
# 14                Illinois
# 15                 Indiana
# 16                    Iowa
# 17                  Kansas
# 18                Kentucky
# 19               Louisiana
# 20                   Maine
# 21                Maryland
# 22           Massachusetts
# 23                Michigan
# 24               Minnesota
# 25             Mississippi
# 26                Missouri
# 27                 Montana
# ...

# %%
print ((ACT_2018).columns)
print ((ACT_2018['State']).nunique)
print ((ACT_2019).info())
ACT_2018.head()
# Out:
# Index(['State', 'participation_18', 'avg_18'], dtype='object')
# <bound method IndexOpsMixin.nunique of 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                   Maine
# 21                Maryland
# 22           Massachusetts
# 23                Michigan
# 24               Minnesota
# 25             Mississippi
# 26                Missouri
# 27                 Montana
# 28                Nebraska
# 29                  Nevada
# ...

# %%
print ((ACT_2019).columns)
print ((ACT_2019['State']).nunique)
print ((ACT_2019).info())
ACT_2019.head()
# Out:
# Index(['State', 'participation_19', 'avg_19'], dtype='object')
# <bound method IndexOpsMixin.nunique of 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# ...

# %%
print ((ACT_2019_ca).columns)
print ((ACT_2019_ca).nunique)
ACT_2019_ca.head().T
# Out:
# Index(['CDS', 'CCode', 'CDCode', 'SCode', 'RType', 'SName', 'DName', 'CName',
#        'Enroll12', 'NumTstTakr', 'AvgScrRead', 'AvgScrEng', 'AvgScrMath',
#        'AvgScrSci', 'NumGE21', 'PctGE21', 'Year', 'Unnamed: 17'],
#       dtype='object')
# <bound method DataFrame.nunique of                CDS  CCode     CDCode      SCode RType  \
# 0     3.366993e+13   33.0  3366993.0   129882.0     S
# 1     1.964212e+13   19.0  1964212.0  1995596.0     S
# 2     1.563776e+13   15.0  1563776.0  1530377.0     S
# 3     4.369666e+13   43.0  4369666.0  4333795.0     S
# 4     1.964733e+13   19.0  1964733.0  1935121.0     S
# ...            ...    ...        ...        ...   ...
# 2305  5.810588e+13   58.0  5810587.0  5830112.0     S
# 2306  3.667959e+13   36.0  3667959.0  3638509.0     S
# 2307  3.667777e+13   36.0  3667777.0  3638616.0     S
# 2308  3.667850e+13   36.0  3667850.0  3630530.0     S
# 2309           NaN    NaN        NaN        NaN   NaN
#
# ...

# %% [markdown]
# ### Cleaning data ACT

# %%
# decided not to include the National as a whole and the territories of the US

ACT_2017 = ACT_2017[ACT_2017['State'] != "Virgin Islands"]
ACT_2018 = ACT_2018[ACT_2018['State'] != "Virgin Islands"]
ACT_2019 = ACT_2019[ACT_2019['State'] != "Virgin Islands"]
ACT_2017 = ACT_2017[ACT_2017['State'] != "Puerto Rico"]
ACT_2018 = ACT_2018[ACT_2018['State'] != "Puerto Rico"]
ACT_2019 = ACT_2019[ACT_2019['State'] != "Puerto Rico"]
ACT_2017 = ACT_2017[ACT_2017['State'] != "National"]
ACT_2018 = ACT_2018[ACT_2018['State'] != "National"]
ACT_2019 = ACT_2019[ACT_2019['State'] != "National"]

# %%
print(ACT_2017.info())
ACT_2017.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 1 to 51
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             51 non-null     object
#  1   participation_17  51 non-null     object
#  2   avg_17            51 non-null     object
# dtypes: object(3)
# memory usage: 1.6+ KB
# None
#         State participation_17 avg_17
# 1     Alabama             100%   19.2
# 2      Alaska              65%   19.8
# 3     Arizona              62%   19.7
# 4    Arkansas             100%   19.4
# 5  California              31%   22.8

# %%
ACT_2018[ACT_2018['State'] =='South Dakota']
# Out:
#            State participation_18  avg_18
# 42  South Dakota              77%    21.9

# %%
print(ACT_2019.info())
ACT_2019['State'].unique
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             51 non-null     object
#  1   participation_19  51 non-null     object
#  2   avg_19            51 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB
# None
# <bound method Series.unique of 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# ...

# %% [markdown]
# ### Merging data files  ACT

# %%
# Merge three ACT files base on State
merge_17_18 = pd.merge(ACT_2017, ACT_2018, on='State', how='inner')

#Merge to 2019 ACT, given the name merge_sat
merge_act = pd.merge(merge_17_18, ACT_2019, on='State', how='inner')

#replacing % in ACT_2017 to standardized the information
merge_act['participation_17'] = merge_act['participation_17'].replace({'%':''}, regex = True)
merge_act['participation_18'] = merge_act['participation_18'].replace({'%':''}, regex = True)
merge_act['participation_19'] = merge_act['participation_19'].replace({'%':''}, regex = True)

merge_act['participation_17'] = merge_act['participation_17'].apply(pd.to_numeric, errors = 'coerce')
merge_act['participation_18'] = merge_act['participation_18'].apply(pd.to_numeric, errors = 'coerce')
merge_act['participation_19'] = merge_act['participation_19'].apply(pd.to_numeric, errors = 'coerce')
#checking 
merge_act
# Out:
#              State  participation_17 avg_17  participation_18  avg_18  \
# 0          Alabama               100   19.2               100    19.1
# 1           Alaska                65   19.8                33    20.8
# 2          Arizona                62   19.7                66    19.2
# 3         Arkansas               100   19.4               100    19.4
# 4       California                31   22.8                27    22.7
# 5         Colorado               100   20.8                30    23.9
# 6      Connecticut                31   25.2                26    25.6
# 7         Delaware                18   24.1                17    23.8
# 8          Florida                73   19.8                66    19.9
# 9          Georgia                55   21.4                53    21.4
# 10          Hawaii                90   19.0                89    18.9
# 11           Idaho                38   22.3                36    22.3
# ...

# %%
merge_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             51 non-null     object
#  1   participation_17  51 non-null     int64
#  2   avg_17            51 non-null     object
#  3   participation_18  51 non-null     int64
#  4   avg_18            51 non-null     float64
#  5   participation_19  51 non-null     int64
#  6   avg_19            51 non-null     float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 2.9+ KB

# %%
#applying to numeric for further calculation
merge_act['participation_17'] = merge_act['participation_17'].apply(pd.to_numeric, errors = 'coerce')
merge_act['avg_17'] = merge_act['avg_17'].apply(pd.to_numeric, errors = 'coerce')

# %%
#rechecking the info
merge_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             51 non-null     object
#  1   participation_17  51 non-null     int64
#  2   avg_17            50 non-null     float64
#  3   participation_18  51 non-null     int64
#  4   avg_18            51 non-null     float64
#  5   participation_19  51 non-null     int64
#  6   avg_19            51 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 2.9+ KB

# %%
merge_sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Alabama to Wyoming
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   participation_17  51 non-null     int64
#  1   eng_17            51 non-null     int64
#  2   math_17           51 non-null     int64
#  3   total_17          51 non-null     int64
#  4   participation_18  51 non-null     int64
#  5   eng_18            51 non-null     int64
#  6   math_18           51 non-null     int64
#  7   total_18          51 non-null     int64
#  8   participation_19  51 non-null     int64
#  9   eng_19            51 non-null     int64
#  10  math_19           51 non-null     int64
#  11  total_19          51 non-null     int64
# dtypes: int64(12)
# memory usage: 5.2+ KB

# %% [markdown]
# # Analysis Data & Visualization

# %% [markdown]
# ## SAT

# %%
merge_sat.columns
# Out:
# Index(['participation_17', 'eng_17', 'math_17', 'total_17', 'participation_18',
#        'eng_18', 'math_18', 'total_18', 'participation_19', 'eng_19',
#        'math_19', 'total_19'],
#       dtype='object')

# %%
# what is the max, min, median of the data in SAT exam?
merge_sat.describe()
# Out:
#        participation_17      eng_17     math_17     total_17  \
# count         51.000000   51.000000   51.000000    51.000000
# mean          39.803922  569.117647  547.627451  1126.098039
# std           35.276632   45.666901   84.909119    92.494812
# min            2.000000  482.000000   52.000000   950.000000
# 25%            4.000000  533.500000  522.000000  1055.500000
# 50%           38.000000  559.000000  548.000000  1107.000000
# 75%           66.000000  613.000000  599.000000  1212.000000
# max          100.000000  644.000000  651.000000  1295.000000
#
#        participation_18      eng_18     math_18     total_18  \
# count         51.000000   51.000000   51.000000    51.000000
# mean          45.745098  563.686275  556.235294  1120.019608
# std           37.314256   47.502627   47.772623    94.155083
# min            2.000000  480.000000  480.000000   977.000000
# 25%            4.500000  534.500000  522.500000  1057.500000
# ...

# %%
# what are the state that has the 100% participation?
print(merge_sat[merge_sat['participation_17']==100].index)
len(merge_sat[merge_sat['participation_17']==100].index)
# Out:
# Index(['Connecticut', 'Delaware', 'District of Columbia', 'Michigan'], dtype='object', name='State')
# 4

# %%
merge_sat['participation_17'] = merge_sat['participation_17'].apply(pd.to_numeric, errors = 'coerce')
merge_sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Alabama to Wyoming
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   participation_17  51 non-null     int64
#  1   eng_17            51 non-null     int64
#  2   math_17           51 non-null     int64
#  3   total_17          51 non-null     int64
#  4   participation_18  51 non-null     int64
#  5   eng_18            51 non-null     int64
#  6   math_18           51 non-null     int64
#  7   total_18          51 non-null     int64
#  8   participation_19  51 non-null     int64
#  9   eng_19            51 non-null     int64
#  10  math_19           51 non-null     int64
#  11  total_19          51 non-null     int64
# dtypes: int64(12)
# memory usage: 7.2+ KB

# %%
# correlation between participation and score?
corr = merge_sat.corr(numeric_only = True)

# %%
# Create a heatmap to show the correlation
mask = np.zeros(merge_sat.corr().shape, dtype=bool)
mask[np.triu_indices(len(mask))] = True

plt.figure(figsize=(16,12))
plt.title('Heatmap between numeric features of SAT in 2017-19', fontsize=14)
sns.heatmap(merge_sat.corr(), cmap='PuBu', annot=True, mask=mask);

# %%
# Plot the histogram
mean = np.mean(merge_sat['participation_17'])
fig, ax = plt.subplots(figsize=(7, 4), sharex=False, sharey=True)

sns.histplot(data=merge_sat, x='participation_17', color='lightblue', ax=ax, kde=False, bins=8)

#mean line
ax.axvline(mean, ls='dashdot', color='red')

# Set x and y labels
ax.set_xlabel('Participation (%)')
ax.set_ylabel('No. of States')

# give title
ax.set_title(f'SAT Participation in 2017 (Mean: {mean:.1f})')



# Display the plot
plt.show()

# %%
# Plot the histogram
mean = np.mean(merge_sat['participation_18'])
fig, ax = plt.subplots(figsize=(7, 4), sharex=False, sharey=True)

sns.histplot(data=merge_sat, x='participation_18', color='lightblue', ax=ax, kde=False, bins=8)

#mean line
ax.axvline(mean, ls='dashdot', color='red')

# Set x and y labels
ax.set_xlabel('Participation (%)')
ax.set_ylabel('No. of States')

# give title
ax.set_title(f'SAT Participation in 2018 (Mean: {mean:.1f})')



# Display the plot
plt.show()

# %%
# Plot the histogram
mean = np.mean(merge_sat['participation_19'])
fig, ax = plt.subplots(figsize=(7, 4), sharex=False, sharey=True)

sns.histplot(data=merge_sat, x='participation_19', color='lightblue', ax=ax, kde=False, bins=8)

#mean line
ax.axvline(mean, ls='dashdot', color='red')

# Set x and y labels
ax.set_xlabel('Participation (%)')
ax.set_ylabel('No. of States')

# give title
ax.set_title(f'SAT Participation in 2019 (Mean: {mean:.1f})')



# Display the plot
plt.show()

# %%
# Plot the histogram
mean0 = np.mean(merge_sat['participation_17'])
mean1 = np.mean(merge_sat['participation_18'])
mean2 = np.mean(merge_sat['participation_19'])
fig, ax = plt.subplots(nrows =3,figsize=(7, 16), sharex=False, sharey=True)

sns.histplot(data=merge_sat, x='participation_17', color='lightblue', ax=ax[0], kde=False, bins=8)

#1st plot
#mean line
ax[0].axvline(mean0, ls='dashdot', color='red')

# Set x and y labels
ax[0].set_xlabel('Participation (%)')
ax[0].set_ylabel('No. of States')

# give title
ax[0].set_title(f'SAT Participation in 2017 (Mean: {mean0:.1f})')

#2nd plot
sns.histplot(data=merge_sat, x='participation_18', color='lightblue', ax=ax[1], kde=False, bins=8)
ax[1].set_title(f'SAT Participation in 2018 (Mean: {mean1:.1f})')
ax[1].set_xlabel('Participation (%)')
ax[1].set_ylabel('No. of States')
ax[1].axvline(mean1, ls='dashdot', color='red')


#3rd plot
sns.histplot(data=merge_sat, x='participation_19', color='lightblue', ax=ax[2], kde=False, bins=8)
ax[2].set_title(f'SAT Participation in 2019 (Mean: {mean2:.1f})')
ax[2].set_xlabel('Participation (%)')
ax[2].set_ylabel('No. of States')
ax[2].axvline(mean2, ls='dashdot', color='red')

# Display the plot
plt.show()

# %%
# which state that has SAT total score below the avg on that year
#2017
print(merge_sat[merge_sat['total_17'] < merge_sat['total_17'].median()].index)
len(merge_sat[merge_sat['total_17'] < merge_sat['total_17'].median()].index)
# Out:
# Index(['Alaska', 'California', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Indiana', 'Maine', 'Maryland', 'Michigan', 'New Hampshire',
#        'New Jersey', 'New York', 'North Carolina', 'Oklahoma', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'Texas', 'Virginia', 'Washington',
#        'West Virginia'],
#       dtype='object', name='State')
# 25

# %%
# which state that has SAT total score below the avg on that year
#2018
print(merge_sat[merge_sat['total_18'] < merge_sat['total_18'].median()].index)
len(merge_sat[merge_sat['total_18'] < merge_sat['total_18'].median()].index)
# Out:
# Index(['California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Georgia', 'Hawaii', 'Idaho', 'Illinois',
#        'Indiana', 'Maine', 'Maryland', 'Michigan', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'Oklahoma', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'Texas', 'Utah', 'Washington',
#        'West Virginia'],
#       dtype='object', name='State')
# 25

# %%
# which state that has SAT total score below the avg on that year
#2019
print(merge_sat[merge_sat['total_19'] < merge_sat['total_19'].median()].index)
len(merge_sat[merge_sat['total_19'] < merge_sat['total_19'].median()].index)
# Out:
# Index(['California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Idaho', 'Illinois',
#        'Indiana', 'Maine', 'Maryland', 'Michigan', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'Oklahoma', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'Texas', 'Washington',
#        'West Virginia'],
#       dtype='object', name='State')
# 24

# %%
def plot_box_sat(df, title, ls_columns, x_label, y_label, test_type=False, oreint = 'h'):
    plt.figure(figsize=(13,6))
    plt.title(title)
    
    # Create the boxplot with the corrected 'palette' argument
    ax = sns.boxplot(data=df[ls_columns], color  ='lightblue')
    
    # Set x and y labels
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    
    # Show the plot
    plt.show()

# %%
plot_box_sat(merge_sat, 'SAT participation in 2017-19', ['participation_17', 'participation_18', 'participation_19'], 
         'Year', 'Participation Rate')
plt.savefig('../images/SAT participation in 2017-19.png', format='png')

# %%
merge_sat
# Out:
#                       participation_17  eng_17  math_17  total_17  \
# State
# Alabama                              5     593      572      1165
# Alaska                              38     547      533      1080
# Arizona                             30     563      553      1116
# Arkansas                             3     614      594      1208
# California                          53     531      524      1055
# Colorado                            11     606      595      1201
# Connecticut                        100     530      512      1041
# Delaware                           100     503      492       996
# District of Columbia               100     482      468       950
# Florida                             83     520      497      1017
# Georgia                             61     535      515      1050
# Hawaii                              55     544      541      1085
# Idaho                               93     513      493      1005
# ...

# %%
#merge_sat["total_17"] != merge_sat["math_17"] + merge_sat["eng_17"]
i=merge_sat[merge_sat["math_17"] < 200]

# %%
merge_sat.iloc[20, 2] = 1060-536

# %%
merge_sat[merge_sat["math_17"] < 200]
# Out:
# Empty DataFrame
# Columns: [participation_17, eng_17, math_17, total_17, participation_18, eng_18, math_18, total_18, participation_19, eng_19, math_19, total_19]
# Index: []

# %%
plot_box_sat(merge_sat, 'SAT Scores in 2017-19', ['math_17', 'math_18', 'math_19'], 
         'Year', 'Average Scores')

# %%
# Investigate whether states with higher participation rates tend to have lower or higher average scores
corr_sat17 = merge_sat['participation_17'].corr(merge_sat['total_17'])
corr_sat18  =merge_sat['participation_18'].corr(merge_sat['total_18'])
corr_sat19  =merge_sat['participation_19'].corr(merge_sat['total_19'])

#2017
# Establish the size of the figure.
plt.figure(figsize = (7, 5))

# Create scatterplot of participation rate vs avg score.
plt.scatter(merge_sat['participation_17'], merge_sat['total_17'])

plt.title(f'SAT Participation Rate vs Average Score in 2017 \n (Correlation: {corr_sat18:.1f})')
plt.ylabel("Average Score", fontsize = 15)
plt.xlabel("Participation Rate", fontsize = 15);
plt.savefig('../images/sat_participation_vs_score_2017.png', format='png')

# %%
#2018
# Establish the size of the figure.
plt.figure(figsize = (7, 5))

# Create scatterplot of participation rate vs avg score.
plt.scatter(merge_sat['participation_18'], merge_sat['total_18'])

plt.title(f'SAT Participation Rate vs Average Score in 2018 \n (Correlation: {corr_sat18:.1f})')
plt.ylabel("Average Score", fontsize = 15)
plt.xlabel("Participation Rate", fontsize = 15);


plt.savefig('../images/sat_participation_vs_score_2018.png', format='png')

# %%
#2019
# Establish the size of the figure.
plt.figure(figsize = (7, 5))

# Create scatterplot of participation rate vs avg score.
plt.scatter(merge_sat['participation_19'], merge_sat['total_19'], color = 'Black')
plt.scatter(merge_sat['participation_18'], merge_sat['total_18'], color = 'purple')
plt.scatter(merge_sat['participation_17'], merge_sat['total_17'], color = 'Blue')

plt.title(f'SAT Participation Rate vs Average Score in 2017-19 \n (Correlation: {corr_sat18:.1f})')
plt.ylabel("Average Score", fontsize = 15)
plt.xlabel("Participation Rate", fontsize = 15);


plt.savefig('../images/sat_participation_vs_score_2017-19.png', format='png')

# %% [markdown]
# ## ACT

# %%
merge_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             51 non-null     object
#  1   participation_17  51 non-null     int64
#  2   avg_17            50 non-null     float64
#  3   participation_18  51 non-null     int64
#  4   avg_18            51 non-null     float64
#  5   participation_19  51 non-null     int64
#  6   avg_19            51 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 2.9+ KB

# %%
# what is the max, min, median of the data in ACT exam?
merge_act.describe()
# Out:
#        participation_17     avg_17  participation_18     avg_18  \
# count         51.000000  50.000000         51.000000  51.000000
# mean          64.784314  21.548000         61.235294  21.503922
# std           32.806288   2.035024         34.648283   2.120279
# min            8.000000  17.800000          7.000000  17.700000
# 25%           31.000000  19.800000         27.000000  19.950000
# 50%           69.000000  21.400000         66.000000  21.300000
# 75%          100.000000  23.600000        100.000000  23.750000
# max          100.000000  25.500000        100.000000  25.600000
#
#        participation_19     avg_19
# count         51.000000  51.000000
# mean          58.156863  21.480392
# std           35.104628   2.212150
# min            6.000000  17.900000
# 25%           23.500000  19.800000
# 50%           54.000000  21.100000
# 75%          100.000000  23.900000
# max          100.000000  25.500000

# %%
# what are the state that has the 100% participation?
print(merge_act[merge_act['participation_17']==100].State)
len(merge_act[merge_act['participation_17']==100].State)
# Out:
# 0            Alabama
# 3           Arkansas
# 5           Colorado
# 16          Kentucky
# 17         Louisiana
# 23         Minnesota
# 24       Mississippi
# 25          Missouri
# 26           Montana
# 28            Nevada
# 33    North Carolina
# 36          Oklahoma
# 40    South Carolina
# 42         Tennessee
# 44              Utah
# 49         Wisconsin
# 50           Wyoming
# Name: State, dtype: object
# 17

# %%
# correlation between participation and score?
corr = merge_act.corr(numeric_only = True)

# %%
# Create a heatmap to show the correlation
mask = np.zeros(merge_sat.corr().shape, dtype=bool)
mask[np.triu_indices(len(mask))] = True

plt.figure(figsize=(16,12))
plt.title('Heatmap between numeric features of ACT in 2017-19', fontsize=14)
sns.heatmap(merge_sat.corr(), cmap='YlGn', annot=True, mask=mask);

# %%
# Plot the histogram
mean = np.mean(merge_act['participation_17'])
fig, ax = plt.subplots(figsize=(7, 4), sharex=False, sharey=True)

sns.histplot(data=merge_sat, x='participation_17', color='green', ax=ax, kde=False, bins=8)

#mean line
ax.axvline(mean, ls='dashdot', color='black')

# Set x and y labels
ax.set_xlabel('Participation (%)')
ax.set_ylabel('No. of States')

# give title
ax.set_title(f'ACT Participation in 2017 (Mean: {mean:.1f})')



# Display the plot
plt.show()

# %%
# Plot the histogram
mean = np.mean(merge_act['participation_18'])
fig, ax = plt.subplots(figsize=(7, 4), sharex=False, sharey=True)

sns.histplot(data=merge_sat, x='participation_18', color='green', ax=ax, kde=False, bins=8)

#mean line
ax.axvline(mean, ls='dashdot', color='black')

# Set x and y labels
ax.set_xlabel('Participation (%)')
ax.set_ylabel('No. of States')

# give title
ax.set_title(f'ACT Participation in 2018 (Mean: {mean:.1f})')



# Display the plot
plt.show()

# %%
# Plot the histogram
mean = np.mean(merge_act['participation_19'])
fig, ax = plt.subplots(figsize=(7, 4), sharex=False, sharey=True)

sns.histplot(data=merge_sat, x='participation_19', color='green', ax=ax, kde=False, bins=8)

#mean line
ax.axvline(mean, ls='dashdot', color='black')

# Set x and y labels
ax.set_xlabel('Participation (%)')
ax.set_ylabel('No. of States')

# give title
ax.set_title(f'ACT Participation in 2019 (Mean: {mean:.1f})')



# Display the plot
plt.show()

# %%
merge_act.to_csv('merge_act_tableau.csv', index=True)
merge_sat.to_csv('merge_sat_tableau.csv', index=True)

# %%
merge_act.columns
# Out:
# Index(['State', 'participation_17', 'avg_17', 'participation_18', 'avg_18',
#        'participation_19', 'avg_19'],
#       dtype='object')

# %%
# Investigate whether states with higher participation rates tend to have lower or higher average scores

corr_act17 = merge_act['participation_17'].corr(merge_act['avg_17'])
corr_act18  =merge_act['participation_18'].corr(merge_act['avg_18'])
corr_act19  =merge_act['participation_19'].corr(merge_act['avg_19'])

#2017
# Establish the size of the figure.
plt.figure(figsize = (7, 5))

# Create scatterplot of participation rate vs avg score.
plt.scatter(merge_act['participation_17'], merge_act['avg_17'])

plt.title(f'ACT Participation Rate vs Average Score in 2017 \n (Correlation: {corr_act17:.1f})')
plt.ylabel("Average Score", fontsize = 15)
plt.xlabel("Participation Rate", fontsize = 15);
plt.savefig('../images/act_participation_vs_score_2017.png', format='png')

# %%
#2018
# Establish the size of the figure.
plt.figure(figsize = (7, 5))

# Create scatterplot of participation rate vs avg score.
plt.scatter(merge_act['participation_17'], merge_act['avg_17'], color = 'green')
plt.scatter(merge_act['participation_18'], merge_act['avg_18'], color = 'lightgreen')
plt.scatter(merge_act['participation_19'], merge_act['avg_19'], color = 'black')

plt.title(f'ACT Participation Rate vs Average Score in 2017-19 \n (Correlation: {corr_act18:.1f})')
plt.ylabel("Average Score", fontsize = 15)
plt.xlabel("Participation Rate", fontsize = 15);
plt.savefig('../images/act_participation_vs_score_2017-19.png', format='png')

# %%
#2019
# Establish the size of the figure.
plt.figure(figsize = (7, 5))

# Create scatterplot of participation rate vs avg score.
plt.scatter(merge_act['participation_19'], merge_act['avg_19'])

plt.title(f'ACT Participation Rate vs Average Score in 2019 \n (Correlation: {corr_act19:.1f})')
plt.ylabel("Average Score", fontsize = 15)
plt.xlabel("Participation Rate", fontsize = 15);
plt.savefig('../images/act_participation_vs_score_2019.png', format='png')

# %%
SAT_ACT['Applies to Class Year(s)'].unique()
# Out:
# array(['2021', '2021 2022', 'All / Permanent Policy',
#        '2021 2022 2023 2024', '2021 2022 2023',
#        '2021 2022 2023 2024 2025', nan], dtype=object)

# %%
SAT_ACT[SAT_ACT['Applies to Class Year(s)'] == '2021'].nunique()
# Out:
# School                            196
# Test Optional?                      4
# Applies to Class Year(s)            1
# Policy Details                    172
# Number of Applicants              196
# Accept Rate                       166
# SAT Total 25th-75th Percentile    169
# ACT Total 25th-75th Percentile     57
# dtype: int64

# %%
SAT_ACT[SAT_ACT['Applies to Class Year(s)'] == '2021 2022'].nunique()
# Out:
# School                            11
# Test Optional?                     2
# Applies to Class Year(s)           1
# Policy Details                    11
# Number of Applicants              11
# Accept Rate                       11
# SAT Total 25th-75th Percentile    11
# ACT Total 25th-75th Percentile    10
# dtype: int64

# %%
SAT_ACT[SAT_ACT['Applies to Class Year(s)'] == '2021 2022 2023 2024'].nunique()
# Out:
# School                            9
# Test Optional?                    2
# Applies to Class Year(s)          1
# Policy Details                    4
# Number of Applicants              9
# Accept Rate                       9
# SAT Total 25th-75th Percentile    9
# ACT Total 25th-75th Percentile    8
# dtype: int64

# %%
SAT_ACT[SAT_ACT['Applies to Class Year(s)'] == '2021 2022 2023'].nunique()
# Out:
# School                            15
# Test Optional?                     1
# Applies to Class Year(s)           1
# Policy Details                    15
# Number of Applicants              15
# Accept Rate                       15
# SAT Total 25th-75th Percentile    15
# ACT Total 25th-75th Percentile    10
# dtype: int64

# %%
def plot_box_act(df, title, ls_columns, x_label, y_label, test_type=False, oreint = 'h'):
    plt.figure(figsize=(13,6))
    plt.title(title)
    
    # Create the boxplot with the corrected 'palette' argument
    ax = sns.boxplot(data=df[ls_columns], color  ='lightgreen')
    
    # Set x and y labels
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    
    # Show the plot
    plt.show()

# %%
plot_box_act(merge_act, 'ACT participation in 2017-19', ['participation_17', 'participation_18', 'participation_19'], 
         'Year', 'Participation Rate')
plt.savefig('../images/ACT participation in 2017-19.png', format='png')

# %%
merge_act.describe()

# %%
#which state that has a high participation rate (75% percentile) but low  scores (less than avg)
# Calculate the median of the ACT scores for 2019
median = merge_act['avg_19'].median()

# Filter states with participation rate > 75% and avg ACT score < median
filtered_states = merge_act[(merge_act['participation_19'] > 75) & (merge_act['avg_19'] < median)]

# Select the top 5 states with the highest participation rates
top_5_states_act = filtered_states.nlargest(5, 'participation_19')[['State', 'participation_19', 'avg_19']]

# Display the top 5 states
print(top_5_states_act)
# Out:
#           State  participation_19  avg_19
# 0       Alabama               100    18.9
# 3      Arkansas               100    19.3
# 16     Kentucky               100    19.8
# 17    Louisiana               100    18.8
# 24  Mississippi               100    18.4

# %%
# Set the width for the bars
bar_width = 0.4

# Create positions for the bars on the x-axis
indices = np.arange(len(top_5_states_act['State']))

# Plotting the bar chart
plt.figure(figsize=(10, 6))

# Create the first bar for participation rate
plt.bar(indices, top_5_states_act['participation_19'], width=bar_width, label='Participation Rate', color='lightgreen')

# Create the second bar for average score, slightly shifted to the right by bar_width
plt.bar(indices + bar_width, top_5_states_act['avg_19'], width=bar_width, label='Average Score', color='green')

# Add labels and title
plt.xlabel('State', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.title('Top 5 States with High Participation Rate \n but Low Average Score (ACT 2019)', fontsize=16)

# Add xticks with state names in the middle of the bars
plt.xticks(indices + bar_width / 2, top_5_states_act['State'], rotation=45, ha='right')

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

plt.savefig('../images/Top 5 States with High Participation Rate \n but Low Average Score (ACT 2019).png', format='png')

# %%
# Calculate the median of the SAT scores for 2017
median = merge_sat['total_19'].median()

# Filter states with participation rate > 75% and SAT score < median
filtered_states = merge_sat[(merge_sat['participation_19'] > 75) & (merge_sat['total_19'] < median)]

# Reset index to get the 'State' column back if it's the index
filtered_states = filtered_states.reset_index()

# Select the top 5 states with the highest participation rates
top_5_states_sat = filtered_states.nlargest(5, 'participation_19')[['State', 'participation_19', 'total_19']]

# Display the top 5 states
print(top_5_states_sat)
# Out:
#          State  participation_19  total_19
# 0     Colorado               100      1024
# 1  Connecticut               100      1046
# 2     Delaware               100       985
# 4      Florida               100       999
# 5        Idaho               100       993

# %%
# Set the width for the bars
bar_width = 0.4

# Create positions for the bars on the x-axis
indices = np.arange(len(top_5_states_sat['State']))

# Plotting the bar chart
plt.figure(figsize=(10, 6))

# Create the first bar for participation rate
plt.bar(indices, top_5_states_sat['participation_19'], width=bar_width, label='Participation Rate', color='skyblue')

# Create the second bar for average score, slightly shifted to the right by bar_width
plt.bar(indices + bar_width, top_5_states_sat['total_19'], width=bar_width, label='Average Score', color='blue')

# Add labels and title
plt.xlabel('State', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.title('Top 5 States with High Participation Rate \n but Low Average Score (SAT 2019)', fontsize=16)

# Add xticks with state names in the middle of the bars
plt.xticks(indices + bar_width / 2, top_5_states_sat['State'], rotation=45, ha='right')

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

plt.savefig('../images/Top 5 States with High Participation Rate \n but Low Average Score (SAT 2019).png', format='png')
